# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2

from preprocessor import *
from jigsaw import *


def main():
    jigsaw_image = cv2.imread("../jigsaw-samples/sample_4.png")

    preprocessor = Preprocessor(debug_mode=True)
    processed_jigsaw_image = preprocessor.process(jigsaw_image)

    jigsaw = Jigsaw(jigsaw_image, processed_jigsaw_image)
    jigsaw.visualize()
    for piece in jigsaw.pieces:
        piece.visualize()
    jigsaw.solve()

    return 0

main()
# Out:
# /home/leonardo_abreu/insper/jigsolver/src/piece.py:142: RuntimeWarning: divide by zero encountered in scalar divide
#   slope_ab = (combination[1][1] - combination[0][1]) / (
# /home/leonardo_abreu/insper/jigsolver/src/piece.py:147: RuntimeWarning: divide by zero encountered in scalar divide
#   slope_cd = (combination[3][1] - combination[2][1]) / (
# Found candidates 1
# FLAT (B) 70
# HOLE (G) 0
# HEAD (R) 100
# HEAD (R) 100
# Found candidates 0
# Found candidates 0
# Found candidates 1
# FLAT (B) 70
# HEAD (R) 100
# HEAD (R) 100
# HEAD (R) 100
# Found candidates 0
# Found candidates 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 21
#      17     jigsaw.solve()
#      19     return 0
# ---> 21 main()
#
# Cell In[25], line 16, in main()
#      14 jigsaw.visualize()
#      15 for piece in jigsaw.pieces:
# ---> 16     piece.visualize()
#      17 jigsaw.solve()
#      19 return 0
#
# File ~/insper/jigsolver/src/piece.py:311, in Piece.visualize(self)
#     309 cv2.imshow("Jigsaw Piece", stack_image)
#     310 while True:
# --> 311     key = cv2.waitKey(33)
#     312     if key == 27:
#     313         break
#
# KeyboardInterrupt:
