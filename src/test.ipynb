# %%
# %load_ext autoreload
# %autoreload 2

# %%
import cv2

from jigsaw import Jigsaw
from preprocessor import Preprocessor
from board_viwer import JigsawPuzzleBoardViewer


def main():
    # Show the original image
    jigsaw_image = cv2.imread("../jigsaw-samples/sample_6.png")

    preprocessor = Preprocessor(debug_mode=True)
    processed_jigsaw_image = preprocessor.process(jigsaw_image)

    jigsaw = Jigsaw(jigsaw_image, processed_jigsaw_image, debug_mode=False)

    # jigsaw.visualize()
    # for piece in jigsaw.pieces:
    #     piece.visualize()

    solved_jigsaw = jigsaw.solve()

    board_viewer = JigsawPuzzleBoardViewer(solved_jigsaw)
    board_viewer.display_board()

    pass

    return 0

main()
# Out:
# Found candidates 0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 30
#      26     pass
#      28     return 0
# ---> 30 main()
#
# Cell In[2], line 21, in main()
#      15 jigsaw = Jigsaw(jigsaw_image, processed_jigsaw_image, debug_mode=False)
#      17 # jigsaw.visualize()
#      18 # for piece in jigsaw.pieces:
#      19 #     piece.visualize()
# ---> 21 solved_jigsaw = jigsaw.solve()
#      23 board_viewer = JigsawPuzzleBoardViewer(solved_jigsaw)
#      24 board_viewer.display_board()
#
# File ~/insper/jigsolver/src/jigsaw.py:98, in Jigsaw.solve(self)
#      96 def solve(self):
#      97     self.board, self.pieces_to_place = self._initialize_board()
# ---> 98     self._place_first_corner()
#      99     self._place_borders()
#     100     return self.board
#
# File ~/insper/jigsolver/src/jigsaw.py:247, in Jigsaw._place_first_corner(self)
#     245 def _place_first_corner(self):
#     246     # Find and remove the first corner piece from the pieces to place
# --> 247     corner_piece = next(
#     248         piece for piece in self.pieces_to_place if piece.type == PieceType.CORNER
#     249     )
#     250     self.pieces_to_place.remove(corner_piece)
#     252     # Place the corner piece at the top-left corner of the board
#
# File ~/insper/jigsolver/src/jigsaw.py:248, in <genexpr>(.0)
#     245 def _place_first_corner(self):
#     246     # Find and remove the first corner piece from the pieces to place
#     247     corner_piece = next(
# --> 248         piece for piece in self.pieces_to_place if piece.type == PieceType.CORNER
#     249     )
#     250     self.pieces_to_place.remove(corner_piece)
#     252     # Place the corner piece at the top-left corner of the board
#
# AttributeError: 'Piece' object has no attribute 'type'
